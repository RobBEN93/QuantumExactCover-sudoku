# %%
from python_package.data_processing import GenData

# %%
# Define your database URL
DATABASE_URL = "postgresql://my_user:my_password@localhost/my_database"

# %%
# Create an instance of GenData
gen_data_instance = GenData(grid_size=2, num_puzzles=100, db_url=DATABASE_URL)

# %%
# Generate data with a specified number of empty cells
gen_data_instance.generate_data(num_cells_range=(1,16+1))
# Out:
#      missing_cells num_qubits_sim total_gates_simple_encoding  \
# 0                1              2                           9
# 1                1              2                           9
# 2                1              2                           9
# 3                1              2                           9
# 4                1              2                           9
# ...            ...            ...                         ...
# 1695            17            449              13783138014702
# 1696            17            449              13783138014702
# 1697            17            449              13783138014702
# 1698            17            449              13783138014702
# 1699            17            449              13783138014702
#
#      mcx_gates_simple_encoding num_qubits_pat total_gates_pattern_encoding  \
# 0                            1              2                            9
# 1                            1              2                            9
# 2                            1              2                            9
# 3                            1              2                            9
# 4                            1              2                            9
# ...                        ...            ...                          ...
# 1695            12916210342154            545          5034204440287221634
# 1696            12916210342154            545          5034204440287221634
# 1697            12916210342154            545          5034204440287221634
# 1698            12916210342154            545          5034204440287221634
# 1699            12916210342154            545          5034204440287221634
#
#      mcx_gates_pattern_encoding
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 1695        4949092517333129656
# 1696        4949092517333129656
# 1697        4949092517333129656
# 1698        4949092517333129656
# 1699        4949092517333129656
#
# [1700 rows x 7 columns]

# %%
# Insert the generated data into the SQL database
gen_data_instance.insert_into_sql()

# %%
# Load data from the database into a DataFrame
#df = gen_data_instance.load_db_table_to_df('quantum_resources')
